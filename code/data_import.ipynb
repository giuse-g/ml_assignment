# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', 100)

# %%
codebook = pd.read_csv("../data/codebook.csv")

# %%
train = pd.read_csv("../data/train.csv", delimiter=';')

# %%
codebook
# Out:
#     Variable name        Type  \
# 0          target      binary
# 1            v2a1  continuous
# 2          hacdor      binary
# 3           rooms       count
# 4          hacapo      binary
# 5            v14a      binary
# 6          refrig      binary
# 7           v18q1       count
# 8            r4h1       count
# 9            r4h2       count
# 10           r4m1       count
# 11           r4m2       count
# 12       escolari       count
# 13         pared1      binary
# 14         pared2      binary
# 15         pared3      binary
# 16         pared4      binary
# 17         pared5      binary
# 18         pared6      binary
# 19         pared7      binary
# 20          piso1      binary
# 21          piso2      binary
# 22          piso3      binary
# 23         techo1      binary
# 24         techo2      binary
# 25      cielorazo      binary
# 26          water      binary
# 27       electro1      binary
# 28       electro2      binary
# 29       electro3      binary
# 30     sanitario1      binary
# 31     sanitario2      binary
# 32     sanitario3      binary
# 33  energcocinar1      binary
# 34  energcocinar2      binary
# 35  energcocinar3      binary
# 36      elimbasu1      binary
# 37      elimbasu2      binary
# 38      elimbasu3      binary
# 39        epared1      binary
# 40        epared2      binary
# 41        etecho1      binary
# 42        etecho2      binary
# 43          eviv1      binary
# 44          eviv2      binary
# 45            dis      binary
# 46         female      binary
# 47   estadocivil1      binary
# 48   estadocivil2      binary
# 49   estadocivil3      binary
# 50   estadocivil4      binary
# 51   estadocivil5      binary
# 52   estadocivil6      binary
# 53    parentesco1      binary
# 54    parentesco2      binary
# 55    parentesco3      binary
# 56    parentesco4      binary
# 57    parentesco5      binary
# 58    parentesco6      binary
# 59    parentesco7      binary
# 60    parentesco8      binary
# 61    parentesco9      binary
# 62   parentesco10      binary
# 63   parentesco11      binary
# 64      hogar_nin       count
# 65     hogar_adul       count
# 66    hogar_mayor       count
# 67       meaneduc  continuous
# 68     instlevel1      binary
# 69     instlevel2      binary
# 70     instlevel3      binary
# 71     instlevel4      binary
# 72     instlevel5      binary
# 73     instlevel6      binary
# 74     instlevel7      binary
# 75     instlevel8      binary
# 76       bedrooms       count
# 77   overcrowding       count
# 78      tipovivi1      binary
# 79      tipovivi2      binary
# 80      tipovivi3      binary
# 81      tipovivi4      binary
# 82       computer      binary
# 83     television      binary
# 84   qmobilephone       count
# 85         lugar1      binary
# 86         lugar2      binary
# 87         lugar3      binary
# 88         lugar4      binary
# 89         lugar5      binary
# 90          rural      binary
# 91            age  continuous
#
#                                               Meaning
# 0   Target variable to predict. =1 if individual i...
# 1                                Monthly rent payment
# 2                         =1 Overcrowding by bedrooms
# 3                    number of all rooms in the house
# 4                            =1 Overcrowding by rooms
# 5                    =1 has bathroom in the household
# 6                =1 if the household has refrigerator
# 7                    number of tablets household owns
# 8    #Males younger than 12 years of age in the ho...
# 9    #Males 12 years of age and older in the house...
# 10   #Females younger than 12 years of age in the ...
# 11   #Females 12 years of age and older in the hou...
# 12                                 years of schooling
# 13   =1 if predominant material on the outside wal...
# 14   =1 if predominant material on the outside wal...
# 15   =1 if predominant material on the outside wal...
# 16   =1 if predominant material on the outside wal...
# 17   =1 if predominant material on the outside wal...
# 18   =1 if predominant material on the outside wal...
# 19   =1 if predominant material on the outside wal...
# 20   =1 if predominant material on the floor is mo...
# 21   =1 if predominant material on the floor is ce...
# 22    =1 if predominant material on the floor is wood
# 23   =1 if predominant material on the roof is met...
# 24   =1 if predominant material on the roof is fib...
# 25                        =1 if the house has ceiling
# 26          =1 if water provision inside the dwelling
# 27        =1 electricity from cnfl,  ice,  esph/jasec
# 28                  =1 electricity from private plant
# 29                  =1 no electricity in the dwelling
# 30                       =1 no toilet in the dwelling
# 31           =1 toilet connected to sewer or cesspool
# 32                =1 toilet connected to  septic tank
# 33   =1 no main source of energy used for cooking ...
# 34   =1 main source of energy used for cooking ele...
# 35      =1 main source of energy used for cooking gas
# 36      =1 if rubbish disposal mainly by tanker truck
# 37   =1 if rubbish disposal mainly by botan hollow...
# 38           =1 if rubbish disposal mainly by burning
# 39                                =1 if walls are bad
# 40   =1 if walls are regular (the dropped category...
# 41                                 =1 if roof are bad
# 42   =1 if roof are regular (the dropped category ...
# 43                                =1 if floor are bad
# 44   =1 if floor are regular (the dropped category...
# 45                               =1 if disable person
# 46                                       =1 if female
# 47                       =1 if less than 10 years old
# 48                        =1 if free or coupled union
# 49                                      =1 if married
# 50                                     =1 if divorced
# 51                                    =1 if separated
# 52   =1 if widow/er (the dropped category is ‘if s...
# 53                               =1 if household head
# 54                               =1 if spouse/partner
# 55                                 =1 if son/daughter
# 56                             =1 if stepson/daughter
# 57                          =1 if son/daughter in law
# 58                            =1 if grandson/daughter
# 59                                =1 if mother/father
# 60                         =1 if father/mother in law
# 61                               =1 if brother/sister
# 62                        =1 if brother/sister in law
# 63   =1 if other family member (the dropped catego...
# 64            Number of children 0 to 19 in household
# 65                      Number of adults in household
# 66              # of individuals 65+ in the household
# 67        average years of education for adults (18+)
# 68                           =1 no level of education
# 69                              =1 incomplete primary
# 70                                =1 complete primary
# 71             =1 incomplete academic secondary level
# 72               =1 complete academic secondary level
# 73            =1 incomplete technical secondary level
# 74              =1 complete technical secondary level
# 75   =1 undergraduate and higher education (droppe...
# 76                                 number of bedrooms
# 77                                 # persons per room
# 78                        =1 own and fully paid house
# 79                    =1 own,  paying in installments
# 80                                          =1 rented
# 81                                      =1 precarious
# 82   =1 if the household has notebook or desktop c...
# 83                         =1 if the household has TV
# 84                                 # of mobile phones
# 85                                  =1 region Central
# 86                                =1 region Chorotega
# 87                         =1 region Pacifico central
# 88                                   =1 region Brunca
# 89   =1 region Huetar Atlantica (dropped category ...
# 90                   =1 if household is in rural area
# 91                                       Age in years

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7639 entries, 0 to 7638
# Data columns (total 92 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   target         7639 non-null   int64
#  1   v2a1           7639 non-null   float64
#  2   hacdor         7639 non-null   int64
#  3   rooms          7639 non-null   int64
#  4   hacapo         7639 non-null   int64
#  5   v14a           7639 non-null   int64
#  6   refrig         7639 non-null   int64
#  7   v18q1          7639 non-null   int64
#  8   r4h1           7639 non-null   int64
#  9   r4h2           7639 non-null   int64
#  10  r4m1           7639 non-null   int64
#  11  r4m2           7639 non-null   int64
#  12  escolari       7639 non-null   int64
#  13  pared1         7639 non-null   int64
